# %% [markdown]
# ### Window Function

# %% [markdown]
# Group B output ![image.png](attachment:image.png)

# %% [markdown]
# - Task
#     - I dont want to melt/collapsing the number of rows
#     - want to preserve the original row level detail
#     - i want the average to shoiw up at each row ie 4+3+5 / 3 = 4 for 1st group.
#     - for 2nd group its 7+2 / 2 = 4.5
# - for this we use window fuction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Window fuctions
#     - each group in the group by is called partition in window fuction
#     - this can be applied in ranking the columns
#
#
# - Ranking function
#     - Syntax below
#     - inorder to rank the data needs to be sorted by one specific column ( which is order by )
#     - now its ordered and partitioned - now assign row number to each row
#     - for that we use ROW_NUMBER()
#     - followed by thr ROW_NUMBER() we give OVER() fn
#     - inside OVER() we give 2 inputs - PARTITION BY (column) and sorting - ORDER BY (column) AS name of the new col

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Row number() - rank() - dense rank()

# %% [markdown]
# - Row number ()
#     - assign a sequential number despite same values on each row
# - Rank()
#     -  same value gets same rank but with gaps
# - Dense rank()
#     - ranking without gaps
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ROW_NUMBER()
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - if we dont give on what to partition on - then it considers whole data as a table and orderby from row 1
#  - it will give all rows ranked and sorted

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - we need to use aggregate fuction
#     - how do we use partition her ??
#         -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - If we remove the orderBy - we will get cumsum of each partition.
# ![image.png](attachment:image.png)

# %% [markdown]
# - What if we remove the partiton by ??
#     - we get the total market amount
#     - ![image.png](attachment:image.png)

# %% [markdown]
# - No partition by but keeps order by market date
#     - cum sum for each date  on the last same date row
#     - ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - for row lwvwl partitioning we use window framing

# %% [markdown]
# ![image.png](attachment:image.png)
